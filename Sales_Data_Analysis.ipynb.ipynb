# %%
# !pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.read_csv("C:/Users/DELL/Downloads/sales_data.csv")
df.head()
# Out:
#   Order_ID  Order_Date Customer_Name Region Product_Category Product_Name  \
# 0  ORD0001  2023-04-13   Customer_87   East  Office Supplies        Paper
# 1  ORD0002  2023-05-30   Customer_88   West  Office Supplies       Marker
# 2  ORD0003  2023-11-10   Customer_89  North        Furniture         Desk
# 3  ORD0004  2023-11-16   Customer_51   East  Office Supplies      Stapler
# 4  ORD0005  2023-03-30    Customer_9  South      Electronics       Laptop
#
#    Quantity  Unit_Price  Discount    Sales   Profit
# 0         8         198      0.20  1267.20   176.35
# 1         4         113      0.10   406.80    24.93
# 2         5        1284      0.15  5457.00   845.57
# 3         3         117      0.15   298.35    42.77
# 4         7        1397      0.15  8312.15  2020.90
